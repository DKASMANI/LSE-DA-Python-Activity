# %%
import pandas as pd

# %%
food = pd.read_csv('FAO_raw.csv')
food.head()
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG        2.0  Afghanistan     2511.0
# 1               AFG        2.0  Afghanistan     2805.0
# 2               AFG        2.0  Afghanistan     2513.0
# 3               AFG        2.0  Afghanistan     2513.0
# 4               AFG        2.0  Afghanistan     2514.0
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products        5142.0    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)        5142.0    Food  1000 tonnes     33.94
# 2       Barley and products        5521.0    Feed  1000 tonnes     33.94
# 3       Barley and products        5142.0    Food  1000 tonnes     33.94
# 4        Maize and products        5521.0    Feed  1000 tonnes     33.94
#
#    longitude  ...   Y2004   Y2005   Y2006   Y2007   Y2008   Y2009   Y2010  \
# 0      67.71  ...  3249.0  3486.0  3704.0  4164.0  4252.0  4538.0  4605.0
# ...

# %%
food.shape
# Out:
# (21478, 63)

# %%
#List of columnn names (1). 

col_names = list(food)
col_names
# Out:
# ['Area Abbreviation',
#  'Area Code',
#  'Area',
#  'Item Code',
#  'Item',
#  'Element Code',
#  'Element',
#  'Unit',
#  'latitude',
#  'longitude',
#  'Y1961',
#  'Y1962',
#  'Y1963',
#  'Y1964',
#  'Y1965',
#  'Y1966',
#  'Y1967',
#  'Y1968',
#  'Y1969',
#  'Y1970',
#  'Y1971',
#  'Y1972',
#  'Y1973',
#  'Y1974',
#  'Y1975',
#  'Y1976',
#  'Y1977',
#  'Y1978',
#  'Y1979',
#  'Y1980',
#  'Y1981',
#  'Y1982',
#  'Y1983',
#  'Y1984',
#  'Y1985',
#  'Y1986',
#  'Y1987',
#  'Y1988',
#  'Y1989',
#  'Y1990',
#  'Y1991',
#  'Y1992',
#  'Y1993',
#  'Y1994',
#  'Y1995',
#  'Y1996',
#  'Y1997',
#  'Y1998',
#  'Y1999',
#  'Y2000',
#  'Y2001',
#  'Y2002',
#  'Y2003',
#  'Y2004',
#  'Y2005',
#  'Y2006',
#  'Y2007',
#  'Y2008',
#  'Y2009',
#  'Y2010',
#  'Y2011',
#  'Y2012',
#  'Y2013']

# %%
#List of columnn names (2). 

col_names = list(food.columns)
col_names
# Out:
# ['Area Abbreviation',
#  'Area Code',
#  'Area',
#  'Item Code',
#  'Item',
#  'Element Code',
#  'Element',
#  'Unit',
#  'latitude',
#  'longitude',
#  'Y1961',
#  'Y1962',
#  'Y1963',
#  'Y1964',
#  'Y1965',
#  'Y1966',
#  'Y1967',
#  'Y1968',
#  'Y1969',
#  'Y1970',
#  'Y1971',
#  'Y1972',
#  'Y1973',
#  'Y1974',
#  'Y1975',
#  'Y1976',
#  'Y1977',
#  'Y1978',
#  'Y1979',
#  'Y1980',
#  'Y1981',
#  'Y1982',
#  'Y1983',
#  'Y1984',
#  'Y1985',
#  'Y1986',
#  'Y1987',
#  'Y1988',
#  'Y1989',
#  'Y1990',
#  'Y1991',
#  'Y1992',
#  'Y1993',
#  'Y1994',
#  'Y1995',
#  'Y1996',
#  'Y1997',
#  'Y1998',
#  'Y1999',
#  'Y2000',
#  'Y2001',
#  'Y2002',
#  'Y2003',
#  'Y2004',
#  'Y2005',
#  'Y2006',
#  'Y2007',
#  'Y2008',
#  'Y2009',
#  'Y2010',
#  'Y2011',
#  'Y2012',
#  'Y2013']

# %%
# Filter data by columns.

food_usecols = pd.read_csv('FAO_raw.csv', usecols = ['Area', 'Item', 'Element', 'Unit', 'latitude', 'longitude'])
food_usecols.head()
# Out:
#           Area                      Item Element         Unit  latitude  \
# 0  Afghanistan        Wheat and products    Food  1000 tonnes     33.94
# 1  Afghanistan  Rice (Milled Equivalent)    Food  1000 tonnes     33.94
# 2  Afghanistan       Barley and products    Feed  1000 tonnes     33.94
# 3  Afghanistan       Barley and products    Food  1000 tonnes     33.94
# 4  Afghanistan        Maize and products    Feed  1000 tonnes     33.94
#
#    longitude
# 0      67.71
# 1      67.71
# 2      67.71
# 3      67.71
# 4      67.71

# %%
# Filter data by rows. 

food_nrows = pd.read_csv('FAO_raw.csv', nrows = 10)
food_nrows
# Out:
#   Area Abbreviation  Area Code         Area  Item Code  \
# 0               AFG          2  Afghanistan       2511
# 1               AFG          2  Afghanistan       2805
# 2               AFG          2  Afghanistan       2513
# 3               AFG          2  Afghanistan       2513
# 4               AFG          2  Afghanistan       2514
# 5               AFG          2  Afghanistan       2514
# 6               AFG          2  Afghanistan       2517
# 7               AFG          2  Afghanistan       2520
# 8               AFG          2  Afghanistan       2531
# 9               AFG          2  Afghanistan       2536
#
#                        Item  Element Code Element         Unit  latitude  \
# 0        Wheat and products          5142    Food  1000 tonnes     33.94
# 1  Rice (Milled Equivalent)          5142    Food  1000 tonnes     33.94
# 2       Barley and products          5521    Feed  1000 tonnes     33.94
# ...

# %%
# Skip rows (1). 

food_skiprows = pd.read_csv('FAO_raw.csv', skiprows = 3)
food_skiprows.head()
# Out:
#    AFG    2  Afghanistan    2513  Barley and products    5521  Feed  \
# 0  AFG  2.0  Afghanistan  2513.0  Barley and products  5142.0  Food
# 1  AFG  2.0  Afghanistan  2514.0   Maize and products  5521.0  Feed
# 2  AFG  2.0  Afghanistan  2514.0   Maize and products  5142.0  Food
# 3  AFG  2.0  Afghanistan  2517.0  Millet and products  5142.0  Food
# 4  AFG  2.0  Afghanistan  2520.0       Cereals, Other  5142.0  Food
#
#    1000 tonnes  33.94  67.71  ...     58    236    262    263    230    379  \
# 0  1000 tonnes  33.94  67.71  ...  185.0   43.0   44.0   48.0   62.0   55.0
# 1  1000 tonnes  33.94  67.71  ...  120.0  208.0  233.0  249.0  247.0  195.0
# 2  1000 tonnes  33.94  67.71  ...  231.0   67.0   82.0   67.0   69.0   71.0
# 3  1000 tonnes  33.94  67.71  ...   15.0   21.0   11.0   19.0   21.0   18.0
# 4  1000 tonnes  33.94  67.71  ...    2.0    1.0    1.0    0.0    0.0    0.0
#
#      315    203    367    360
# 0   60.0   72.0   78.0   89.0
# 1  178.0  191.0  200.0  200.0
# ...

# %%
food.tail()
# Out:
#                                        Area Abbreviation  Area Code      Area  \
# 21473                                                ZWE      181.0  Zimbabwe
# 21474                                                ZWE      181.0  Zimbabwe
# 21475                                                ZWE      181.0  Zimbabwe
# 21476                                                ZWE      181.0  Zimbabwe
# 21477  Notes: Lots of missing data represented by eit...        NaN       NaN
#
#        Item Code                     Item  Element Code Element         Unit  \
# 21473     2960.0            Fish, Seafood        5521.0    Feed  1000 tonnes
# 21474     2960.0            Fish, Seafood        5142.0    Food  1000 tonnes
# 21475     2961.0  Aquatic Products, Other        5142.0    Food  1000 tonnes
# 21476     2928.0            Miscellaneous        5142.0    Food  1000 tonnes
# 21477        NaN                      NaN           NaN     NaN          NaN
#
# ...

# %%
# Skip bottom row (footer). 

food_skipfooter = pd.read_csv('FAO_raw.csv', skipfooter = 1)
food_skipfooter.tail()
# Out:
# C:\Users\opanj\AppData\Local\Temp\ipykernel_20924\1815107530.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   food_skipfooter = pd.read_csv('FAO_raw.csv', skipfooter = 1)
#       Area Abbreviation  Area Code      Area  Item Code  \
# 21472               ZWE        181  Zimbabwe       2948
# 21473               ZWE        181  Zimbabwe       2960
# 21474               ZWE        181  Zimbabwe       2960
# 21475               ZWE        181  Zimbabwe       2961
# 21476               ZWE        181  Zimbabwe       2928
#
#                           Item  Element Code Element         Unit  latitude  \
# 21472  Milk - Excluding Butter          5142    Food  1000 tonnes    -19.02
# 21473            Fish, Seafood          5521    Feed  1000 tonnes    -19.02
# 21474            Fish, Seafood          5142    Food  1000 tonnes    -19.02
# ...
