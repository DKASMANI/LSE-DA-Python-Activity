# %%
# The code is syntactically incorrect and it's almost unreadable
# Firstly, code is not giving output
# Secondly, there are unnecessary white spaces and blank lines
# Thirdly, functions are using capital letters
# Fourth, wrong use of indentation with extra tab spaces
# Fifth, one line is exceeding the 76 characters
# Next, there are spelling errors in the comments and functions
# Lastly, comments and functions are not close to margin
 

# Program To Make Simple Calculator
# This function adds 2 numbers
# Removed unnecessary space in below function
def add(x, y):
    return x + y

# This function subtracts 2 numbers
# Space is added after # in the comment line
# Removed one space after 'subtracts' in comment line
def subtract(x, y):
    return x - y

# This function multiplies 2 numbers
# Removed white space above comment line
# Corrected spelling multiplies
# Removed space before comment line
# Added one space after # in the comment line
def multiply(x, y):
    return x * y

# This function divides 2 numbers
# Removed one # in the comment line
# Removed # sign in the end of the comment line
def divide(x, y):
    return x / y

# Removed one space after brackets braces in the print function below
# Removed dot after 'Select operation'
print ("Select operation:")
print ("1.Add")
print ("2.Subtract")
print ("3.Multiply")
print ("4.Divide")

# while True:
# What does 'while True' refer to? Not clear, suggest to remove it
# Included # before comment above
# Moved function close to margin

choice = input ("Enter choice(1/2/3/4): ")

# Take input from the user
# Moved comment above to new line
# Moved all lines below this comment close to the margin
# Removed all unnecessary space in functions
# Used four spaces for indentation before print and Num functions
# Made comment below shorter and corrected spelling mistake in notebook
# What does IDE mean? Too long and not clear comment
# Check if choice is one of the four options in the IDE of your choice or notebook
if choice in ('1', '2', '3', '4'):
    Num1 = float(input("Enter first number: "))
    Num2 = float(input("Enter second number: "))

if choice == '1':
    print(Num1, "+", Num2, "=", add(Num1,Num2))

elif choice == '2':
    print (Num1, "-", Num2, "=", subtract(Num1,Num2))

elif choice == '3':
    print (Num1, "*", Num2, "=", multiply(Num1,Num2))

elif choice == '4':
    print (Num1, "/", Num2, "=", divide(Num1,Num2))

else:
    print("Invalid Input")
    
# This prints the invalid input
# Moved the above comment to new line, removed dots
# Started last comment with capital letter, corrected spelling
# Removed 'break' after last elif function
# print changed to small letters
# Out:
# Select operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 1
# Enter first number: 10
# Enter second number: 5
# 10.0 + 5.0 = 15.0

# %% [markdown]
# # Code without comments to follow PEP8 guidelines:

# %%
# Program To Make Simple Calculator

# This function adds 2 numbers
def add(x, y):
    return x + y

# This function subtracts 2 numbers
def subtract(x, y):
    return x - y

# This function multiplies 2 numbers
def multiply(x, y):
    return x * y

# This function divides 2 numbers
def divide(x, y):
    return x / y

print ("Select operation:")
print ("1.Add")
print ("2.Subtract")
print ("3.Multiply")
print ("4.Divide")


choice = input ("Enter choice(1/2/3/4): ")

# Take input from the user
# Check if choice is one of the four options 
if choice in ('1', '2', '3', '4'):
    Num1 = float(input("Enter first number: "))
    Num2 = float(input("Enter second number: "))

if choice == '1':
    print(Num1, "+", Num2, "=", add(Num1,Num2))

elif choice == '2':
    print (Num1, "-", Num2, "=", subtract(Num1,Num2))

elif choice == '3':
    print (Num1, "*", Num2, "=", multiply(Num1,Num2))

elif choice == '4':
    print (Num1, "/", Num2, "=", divide(Num1,Num2))

else:
    print( "Invalid Input" )
    
# This prints the invalid input
# Out:
# Select operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 50
# Invalid Input
